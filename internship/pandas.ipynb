# %%
import pandas as pd

# %%
dict={'a':[1,2,3,4,5],'b':[6,7,8,9,0],'c':[1,2,7,8,9],'d':[1,3,5,7,9]}
print(dict)
# Out:
# {'a': [1, 2, 3, 4, 5], 'b': [6, 7, 8, 9, 0], 'c': [1, 2, 7, 8, 9], 'd': [1, 3, 5, 7, 9]}

# %%
a=pd.DataFrame(dict)
a
#to change index
v=pd.DataFrame(dict,index=[1,2,3,4,5])
v
# Out:
#    a  b  c  d
# 1  1  6  1  1
# 2  2  7  2  3
# 3  3  8  7  5
# 4  4  9  8  7
# 5  5  0  9  9

# %%
name=['abc','qwe','asd','zxc','rty']
degree=['qaz','wsx','edc','rfv','tgb']
age=[20,21,22,23,24]
rank=[1,2,3,4,5]
dict={'name':name,'degree':degree,'age':age,'rank':rank}
a=pd.DataFrame(dict,index=['a','b','c','d','e'])
a
# Out:
#   name degree  age  rank
# a  abc    qaz   20     1
# b  qwe    wsx   21     2
# c  asd    edc   22     3
# d  zxc    rfv   23     4
# e  rty    tgb   24     5

# %%
#calling csv files
#z=pd.read_csv('___.csv')
#excel files
#x=pd.read_excel('name.xlsx')

# %%
dict={'a':[1,2,3,4,None],'b':[6,7,None,9,0],'c':[1,2,7,8,9],'d':[1,None,5,7,None]}
q=pd.DataFrame(dict)
q
# Out:
#      a    b  c    d
# 0  1.0  6.0  1  1.0
# 1  2.0  7.0  2  NaN
# 2  3.0  NaN  7  5.0
# 3  4.0  9.0  8  7.0
# 4  NaN  0.0  9  NaN

# %%
z=pd.read_csv('nyc_weather.csv')

z
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
z.shape
# Out:
# (31, 11)

# %%
z.bfill(axis='rows') # axis=0
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
z.bfill(axis='columns') # axis=1
# Out:
#           EST Temperature DewPoint Humidity Sea Level PressureIn  \
# 0    1/1/2016          38       23       52                30.03
# 1    1/2/2016          36       18       46                30.02
# 2    1/3/2016          40       21       47                29.86
# 3    1/4/2016          25        9       44                30.05
# 4    1/5/2016          20       -3       41                30.57
# 5    1/6/2016          33        4       35                 30.5
# 6    1/7/2016          39       11       33                30.28
# 7    1/8/2016          39       29       64                 30.2
# 8    1/9/2016          44       38       77                30.16
# 9   1/10/2016          50       46       71                29.59
# 10  1/11/2016          33        8       37                29.92
# 11  1/12/2016          35       15       53                29.85
# 12  1/13/2016          26        4       42                29.94
# ...

# %%
z.ffill(axis=0)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
z.ffill(axis=1)
# Out:
#           EST Temperature DewPoint Humidity Sea Level PressureIn  \
# 0    1/1/2016          38       23       52                30.03
# 1    1/2/2016          36       18       46                30.02
# 2    1/3/2016          40       21       47                29.86
# 3    1/4/2016          25        9       44                30.05
# 4    1/5/2016          20       -3       41                30.57
# 5    1/6/2016          33        4       35                 30.5
# 6    1/7/2016          39       11       33                30.28
# 7    1/8/2016          39       29       64                 30.2
# 8    1/9/2016          44       38       77                30.16
# 9   1/10/2016          50       46       71                29.59
# 10  1/11/2016          33        8       37                29.92
# 11  1/12/2016          35       15       53                29.85
# 12  1/13/2016          26        4       42                29.94
# ...

# %%
z.interpolate()#fill nan values with averages
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
a=z.dropna()#drops rows with null values
a
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# ...

# %%
z.dropna(inplace=True)#inplace save the dropna value into the same variable
z
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# ...

# %%
#groupby
a=z.groupby('Events')
a

# %%
for Events,data in a:
    print('event: ',Events)
    print('\n')
    print('data: ',data)
# Out:
# event:  Fog-Snow
#
#
# data:            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 16  1/17/2016           36        23        66                 29.78
# 22  1/23/2016           26        21        78                 29.77
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 16                8           6.0            0.05           6  Fog-Snow
# 22                1          16.0            2.31           8  Fog-Snow
#
#     WindDirDegrees
# 16             345
# 22              42
# event:  Rain
#
#
# data:            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# ...

# %%
a.get_group('Fog-Snow')
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 15             340
# 26             311

# %%
a.get_group('Rain')
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 15             340
# 26             311

# %%
c=a.get_group('Snow')
print(c)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 17  1/18/2016           25         6        53                 29.83
# 23  1/24/2016           28        11        53                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 17                9          12.0               T           2   Snow
# 23                8           6.0               T           3   Snow
#
#     WindDirDegrees
# 17             293
# 23             327

# %%
a.max()
# Out:
#                 EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow  1/23/2016           36        23        78                 29.78
# Rain       1/9/2016           47        38        77                 30.16
# Snow      1/24/2016           28        11        53                 29.92
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# Events
# Fog-Snow                8          16.0            2.31           8
# Rain                   10           8.0               T           8
# Snow                    9          12.0               T           3
#
#           WindDirDegrees
# Events
# Fog-Snow             345
# Rain                 340
# Snow                 327

# %%
a.mean()
# Out:
#           Temperature   DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow         31.0  22.000000      72.0             29.775000
# Rain             44.0  32.333333      64.0             29.903333
# Snow             26.5   8.500000      53.0             29.875000
#
#           VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# Events
# Fog-Snow              4.5     11.000000         7.0      193.500000
# Rain                  9.0      7.333333         6.0      242.333333
# Snow                  8.5      9.000000         2.5      310.000000

# %%
a.min()
# Out:
#                 EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow  1/17/2016           26        21        66                 29.77
# Rain      1/16/2016           41        22        45                 29.52
# Snow      1/18/2016           25         6        53                 29.83
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# Events
# Fog-Snow                1           6.0            0.05           6
# Rain                    8           7.0            0.24           3
# Snow                    8           6.0               T           2
#
#           WindDirDegrees
# Events
# Fog-Snow              42
# Rain                  76
# Snow                 293

# %%
a.describe()
# Out:
#          CloudCover                                           DewPoint  \
#               count mean       std  min   25%  50%   75%  max    count
# Events
# Fog-Snow        2.0  7.0  1.414214  6.0  6.50  7.0  7.50  8.0      2.0
# Rain            3.0  6.0  2.645751  3.0  5.00  7.0  7.50  8.0      3.0
# Snow            2.0  2.5  0.707107  2.0  2.25  2.5  2.75  3.0      2.0
#
#                      ...  WindDirDegrees        WindSpeedMPH             \
#                mean  ...             75%    max        count       mean
# Events               ...
# Fog-Snow  22.000000  ...          269.25  345.0          2.0  11.000000
# Rain      32.333333  ...          325.50  340.0          3.0   7.333333
# Snow       8.500000  ...          318.50  327.0          2.0   9.000000
#
#
#                std  min  25%   50%   75%   max
# Events
# Fog-Snow  7.071068  6.0  8.5  11.0  13.5  16.0
# Rain      0.577350  7.0  7.0   7.0   7.5   8.0
# Snow      4.242641  6.0  7.5   9.0  10.5  12.0
#
# ...

# %%
a.size()
# Out:
# Events
# Fog-Snow    2
# Rain        3
# Snow        2
# dtype: int64

# %%
a.count()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow    2            2         2         2                     2
# Rain        3            3         3         3                     3
# Snow        2            2         2         2                     2
#
#           VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  \
# Events
# Fog-Snow                2             2                2           2
# Rain                    3             3                3           3
# Snow                    2             2                2           2
#
#           WindDirDegrees
# Events
# Fog-Snow               2
# Rain                   3
# Snow                   2

# %%
dict1={'city':['a','b','c'],'humidity':[30,40,50],'temp':[25,30,35]}
us=pd.DataFrame(dict1)
# Out:
#   city  humidity  temp
# 0    a        30    25
# 1    b        40    30
# 2    c        50    35

# %%
dict2={'city':['q','w','e'],'humidity':[70,80,90],'temp':[15,10,17]}
ind=pd.DataFrame(dict2)
ind
# Out:
#   city  humidity  temp
# 0    q        70    15
# 1    w        80    10
# 2    e        90    17

# %%
s=pd.concat([us,ind])
s
# Out:
#   city  humidity  temp
# 0    a        30    25
# 1    b        40    30
# 2    c        50    35
# 0    q        70    15
# 1    w        80    10
# 2    e        90    17

# %%
k=s.drop([2])
k
# Out:
#   city  humidity  temp
# 0    a        30    25
# 1    b        40    30
# 0    q        70    15
# 1    w        80    10

# %%
g=pd.concat([us,ind],ignore_index=True)
g
# Out:
#   city  humidity  temp
# 0    a        30    25
# 1    b        40    30
# 2    c        50    35
# 3    q        70    15
# 4    w        80    10
# 5    e        90    17

# %%
g=pd.concat([ind,us],ignore_index=True)
g
# Out:
#   city  humidity  temp
# 0    q        70    15
# 1    w        80    10
# 2    e        90    17
# 3    a        30    25
# 4    b        40    30
# 5    c        50    35

# %%
h=pd.concat([us,ind],keys=['india','us'])
h
# Out:
#         city  humidity  temp
# india 0    a        30    25
#       1    b        40    30
#       2    c        50    35
# us    0    q        70    15
#       1    w        80    10
#       2    e        90    17

# %%
dict1={'city':['a','b','c'],'humidity':[30,40,50]}
q=pd.DataFrame(dict1)
q
# Out:
#   city  humidity
# 0    a        30
# 1    b        40
# 2    c        50

# %%
dict2={'city':['a','b','d'],'temp':[25,30,20]}
w=pd.DataFrame(dict2)
w
# Out:
#   city  temp
# 0    a    25
# 1    b    30
# 2    d    20

# %%
d=pd.merge(w,q,on='city')
d
# Out:
#   city  temp  humidity
# 0    a    25        30
# 1    b    30        40

# %%
c=d.iloc[0:1,:1]
c
# Out:
#   city
# 0    a

# %%
z
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# ...

# %%
n=z.drop(['CloudCover'],axis=1)
n
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn    Events  WindDirDegrees
# 8                 9           8.0               T      Rain              76
# 15                8           7.0            0.24      Rain             340
# 16                8           6.0            0.05  Fog-Snow             345
# 17                9          12.0               T      Snow             293
# ...
