# %%
#dataframe(keys-4,data-6),index,read csv file,dropna,fillna,bfill,interpolate,groupby,discribe,concatenation(keys:seperate),merge,
drop

# %%
import pandas as pd
dict={"name":['hashim','sufina','nazeeya','pooja','rithina','athira'],
      "age":[21,25,32,None,22,21],
      "place":['aroor',None,'qatar','kochi','panavally','edapally'],
      "rank":[5,6,1,3,4,2]}
q=pd.DataFrame(dict,index=[1,2,3,4,5,6])
q
# Out:
#       name   age      place  rank
# 1   hashim  21.0      aroor     5
# 2   sufina  25.0       None     6
# 3  nazeeya  32.0      qatar     1
# 4    pooja   NaN      kochi     3
# 5  rithina  22.0  panavally     4
# 6   athira  21.0   edapally     2

# %%
q.interpolate()
# Out:
#       name   age      place  rank
# 1   hashim  21.0      aroor     5
# 2   sufina  25.0       None     6
# 3  nazeeya  32.0      qatar     1
# 4    pooja  27.0      kochi     3
# 5  rithina  22.0  panavally     4
# 6   athira  21.0   edapally     2

# %%
s=pd.read_csv("nyc_weather.csv")
s
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
a=s.dropna()
a
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# ...

# %%
a=s.fillna(3)
a
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
a=s.ffill('rows')
a
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
d=s.interpolate()
d
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
s.dropna(inplace=True)
s
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# ...

# %%
d=s.groupby("Events")
d

# %%
for Events,Data in d:
    print("events",Events)
    print("\n")
    print("data",Data)
# Out:
# events Fog-Snow
#
#
# data           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 16  1/17/2016           36        23        66                 29.78
# 22  1/23/2016           26        21        78                 29.77
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 16                8           6.0            0.05           6  Fog-Snow
# 22                1          16.0            2.31           8  Fog-Snow
#
#     WindDirDegrees
# 16             345
# 22              42
# events Rain
#
#
# data           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# ...

# %%
d.get_group("Snow")
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 17  1/18/2016           25         6        53                 29.83
# 23  1/24/2016           28        11        53                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 17                9          12.0               T           2   Snow
# 23                8           6.0               T           3   Snow
#
#     WindDirDegrees
# 17             293
# 23             327

# %%
d.describe()
# Out:
#          CloudCover                                           DewPoint  \
#               count mean       std  min   25%  50%   75%  max    count
# Events
# Fog-Snow        2.0  7.0  1.414214  6.0  6.50  7.0  7.50  8.0      2.0
# Rain            3.0  6.0  2.645751  3.0  5.00  7.0  7.50  8.0      3.0
# Snow            2.0  2.5  0.707107  2.0  2.25  2.5  2.75  3.0      2.0
#
#                      ...  WindDirDegrees        WindSpeedMPH             \
#                mean  ...             75%    max        count       mean
# Events               ...
# Fog-Snow  22.000000  ...          269.25  345.0          2.0  11.000000
# Rain      32.333333  ...          325.50  340.0          3.0   7.333333
# Snow       8.500000  ...          318.50  327.0          2.0   9.000000
#
#
#                std  min  25%   50%   75%   max
# Events
# Fog-Snow  7.071068  6.0  8.5  11.0  13.5  16.0
# Rain      0.577350  7.0  7.0   7.0   7.5   8.0
# Snow      4.242641  6.0  7.5   9.0  10.5  12.0
#
# ...

# %%
dict2={"name":['hash','suf','zeeya','ja','rit'],
      "age":[21,25,32,None,22],
      "place":['aroor',None,'tar','kochi','pany'],
      "rank":[5,1,3,4,9]}
p=pd.DataFrame(dict2,index=[1,2,3,4,5])
p
# Out:
#     name   age  place  rank
# 1   hash  21.0  aroor     5
# 2    suf  25.0   None     1
# 3  zeeya  32.0    tar     3
# 4     ja   NaN  kochi     4
# 5    rit  22.0   pany     9

# %%
q
p
# Out:
#     name   age  place  rank
# 1   hash  21.0  aroor     5
# 2    suf  25.0   None     1
# 3  zeeya  32.0    tar     3
# 4     ja   NaN  kochi     4
# 6    rit  22.0   pany     9

# %%
d=pd.concat([q,p],keys=["q","p"])
d
# Out:
#         name   age      place  rank
# q 1   hashim  21.0      aroor     5
#   2   sufina  25.0       None     6
#   3  nazeeya  32.0      qatar     1
#   4    pooja   NaN      kochi     3
#   5  rithina  22.0  panavally     4
#   6   athira  21.0   edapally     2
# p 1     hash  21.0      aroor     5
#   2      suf  25.0       None     1
#   3    zeeya  32.0        tar     3
#   4       ja   NaN      kochi     4
#   6      rit  22.0       pany     9

# %%
d=pd.merge(q,p,on="place")
d
# Out:
#    name_x  age_x  place  rank_x name_y  age_y  rank_y
# 0  hashim   21.0  aroor       5   hash   21.0       5
# 1  sufina   25.0   None       6    suf   25.0       1
# 2   pooja    NaN  kochi       3     ja    NaN       4

# %%
y=q.drop(['place'],axis=1)
y
# Out:
#       name   age  rank
# 1   hashim  21.0     5
# 2   sufina  25.0     6
# 3  nazeeya  32.0     1
# 4    pooja   NaN     3
# 5  rithina  22.0     4
# 6   athira  21.0     2
